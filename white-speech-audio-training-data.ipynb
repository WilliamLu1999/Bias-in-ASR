# %% [markdown]
# Downloading speech data spoken by white people

# %% [markdown]
# !curl -X GET \
#      "https://datasets-server.huggingface.co/rows?dataset=librispeech_asr&config=all&split=train.clean.100&offset=0&length=100"
# -o /Users/will/Downloads/whitespeech_data.json

# %%
import json
import requests
import pandas as pd
from IPython.display import Audio, display
# Open the JSON file for reading
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data = json.load(file)

# %%
data
# Out:
# {'features': [{'feature_idx': 0,
#    'name': 'file',
#    'type': {'dtype': 'string', '_type': 'Value'}},
#   {'feature_idx': 1,
#    'name': 'audio',
#    'type': {'sampling_rate': 16000, '_type': 'Audio'}},
#   {'feature_idx': 2,
#    'name': 'text',
#    'type': {'dtype': 'string', '_type': 'Value'}},
#   {'feature_idx': 3,
#    'name': 'speaker_id',
#    'type': {'dtype': 'int64', '_type': 'Value'}},
#   {'feature_idx': 4,
#    'name': 'chapter_id',
#    'type': {'dtype': 'int64', '_type': 'Value'}},
#   {'feature_idx': 5,
#    'name': 'id',
#    'type': {'dtype': 'string', '_type': 'Value'}}],
#  'rows': [{'row_idx': 0,
#    'row': {'file': '374-180298-0000.flac',
# ...

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data2.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data2 = json.load(file)

# %%
data2
# Out:
# {'features': [{'feature_idx': 0,
#    'name': 'file',
#    'type': {'dtype': 'string', '_type': 'Value'}},
#   {'feature_idx': 1,
#    'name': 'audio',
#    'type': {'sampling_rate': 16000, '_type': 'Audio'}},
#   {'feature_idx': 2,
#    'name': 'text',
#    'type': {'dtype': 'string', '_type': 'Value'}},
#   {'feature_idx': 3,
#    'name': 'speaker_id',
#    'type': {'dtype': 'int64', '_type': 'Value'}},
#   {'feature_idx': 4,
#    'name': 'chapter_id',
#    'type': {'dtype': 'int64', '_type': 'Value'}},
#   {'feature_idx': 5,
#    'name': 'id',
#    'type': {'dtype': 'string', '_type': 'Value'}}],
#  'rows': [{'row_idx': 100,
#    'row': {'file': '374-180299-0034.flac',
# ...

# %%
rows_list = []
for item in data["rows"]:
    row_data = item["row"]
    rows_list.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df = pd.DataFrame(rows_list)
df
# Out:
#     row_idx               id  speaker_id  chapter_id  \
# 0         0  374-180298-0000         374      180298
# 1         1  374-180298-0001         374      180298
# 2         2  374-180298-0002         374      180298
# 3         3  374-180298-0003         374      180298
# 4         4  374-180298-0004         374      180298
# ..      ...              ...         ...         ...
# 95       95  374-180299-0029         374      180299
# 96       96  374-180299-0030         374      180299
# 97       97  374-180299-0031         374      180299
# 98       98  374-180299-0032         374      180299
# 99       99  374-180299-0033         374      180299
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
rows_list2 = []
for item in data2["rows"]:
    row_data = item["row"]
    rows_list2.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df2 = pd.DataFrame(rows_list2)
df2
# Out:
#     row_idx                id  speaker_id  chapter_id  \
# 0       100   374-180299-0034         374      180299
# 1       101   374-180299-0035         374      180299
# 2       102   374-180299-0036         374      180299
# 3       103   374-180299-0037         374      180299
# 4       104   374-180299-0038         374      180299
# ..      ...               ...         ...         ...
# 95      195  7800-283493-0006        7800      283493
# 96      196  7800-283493-0007        7800      283493
# 97      197  7800-283493-0008        7800      283493
# 98      198  7800-283493-0009        7800      283493
# 99      199  7800-283493-0010        7800      283493
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data3.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data3 = json.load(file)
rows_list3 = []
for item in data3["rows"]:
    row_data = item["row"]
    rows_list3.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df3 = pd.DataFrame(rows_list3)
df3
# Out:
#     row_idx                id  speaker_id  chapter_id  \
# 0       200  7800-283493-0011        7800      283493
# 1       201  7800-283493-0012        7800      283493
# 2       202  7800-283493-0013        7800      283493
# 3       203  7800-283493-0014        7800      283493
# 4       204  7800-283493-0015        7800      283493
# ..      ...               ...         ...         ...
# 95      295  2514-149482-0067        2514      149482
# 96      296  2514-149482-0068        2514      149482
# 97      297  2514-149482-0069        2514      149482
# 98      298  2514-149482-0070        2514      149482
# 99      299  2514-149482-0071        2514      149482
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data4.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data4 = json.load(file)
rows_list4 = []
for item in data4["rows"]:
    row_data = item["row"]
    rows_list4.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df4 = pd.DataFrame(rows_list4)
df4
# Out:
#     row_idx                id  speaker_id  chapter_id  \
# 0       300  2514-149482-0072        2514      149482
# 1       301  2514-149482-0073        2514      149482
# 2       302  2514-149482-0074        2514      149482
# 3       303  2514-149482-0075        2514      149482
# 4       304  2514-149482-0076        2514      149482
# ..      ...               ...         ...         ...
# 95      395  3240-131231-0059        3240      131231
# 96      396  3240-131231-0060        3240      131231
# 97      397  3240-131231-0061        3240      131231
# 98      398  3240-131231-0062        3240      131231
# 99      399  3240-131231-0063        3240      131231
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data5.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data5 = json.load(file)
rows_list5 = []
for item in data5["rows"]:
    row_data = item["row"]
    rows_list5.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df5 = pd.DataFrame(rows_list5)
df5
# Out:
#     row_idx                id  speaker_id  chapter_id  \
# 0       400  3240-131231-0064        3240      131231
# 1       401  3240-131231-0065        3240      131231
# 2       402  3240-131231-0066        3240      131231
# 3       403  3240-131231-0067        3240      131231
# 4       404  3240-131231-0068        3240      131231
# ..      ...               ...         ...         ...
# 95      495  1088-134318-0001        1088      134318
# 96      496  1088-134318-0002        1088      134318
# 97      497  1088-134318-0003        1088      134318
# 98      498  1088-134318-0004        1088      134318
# 99      499  1088-134318-0005        1088      134318
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data6.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data6 = json.load(file)
rows_list6 = []
for item in data6["rows"]:
    row_data = item["row"]
    rows_list6.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df6 = pd.DataFrame(rows_list6)
df6
# Out:
#     row_idx                id  speaker_id  chapter_id  \
# 0       500  1088-134318-0006        1088      134318
# 1       501  1088-134318-0007        1088      134318
# 2       502  1088-134318-0008        1088      134318
# 3       503  1088-134318-0009        1088      134318
# 4       504  1088-134318-0010        1088      134318
# ..      ...               ...         ...         ...
# 95      595   5456-58161-0020        5456       58161
# 96      596   5456-58161-0021        5456       58161
# 97      597   5456-58161-0022        5456       58161
# 98      598   5456-58161-0023        5456       58161
# 99      599   5456-58161-0024        5456       58161
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/whitespeech_data7.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data7 = json.load(file)
rows_list7 = []
for item in data7["rows"]:
    row_data = item["row"]
    rows_list7.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df7 = pd.DataFrame(rows_list7)
df7
# Out:
#     row_idx               id  speaker_id  chapter_id  \
# 0       600  5456-58161-0025        5456       58161
# 1       601  5456-58161-0026        5456       58161
# 2       602  5456-58161-0027        5456       58161
# 3       603  5456-58161-0028        5456       58161
# 4       604  5456-62043-0000        5456       62043
# ..      ...              ...         ...         ...
# 95      695  5750-35690-0008        5750       35690
# 96      696  5750-35690-0009        5750       35690
# 97      697  5750-35690-0010        5750       35690
# 98      698  5750-35690-0011        5750       35690
# 99      699  5750-35690-0012        5750       35690
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
white_audio = pd.concat([df,df2,df3,df4,df5,df6,df7],axis=0)
white_audio
# Out:
#     row_idx               id  speaker_id  chapter_id  \
# 0         0  374-180298-0000         374      180298
# 1         1  374-180298-0001         374      180298
# 2         2  374-180298-0002         374      180298
# 3         3  374-180298-0003         374      180298
# 4         4  374-180298-0004         374      180298
# ..      ...              ...         ...         ...
# 95      695  5750-35690-0008        5750       35690
# 96      696  5750-35690-0009        5750       35690
# 97      697  5750-35690-0010        5750       35690
# 98      698  5750-35690-0011        5750       35690
# 99      699  5750-35690-0012        5750       35690
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...

# %%
white_audio.to_csv('/Users/will/Downloads/white_audio.csv')

# %%
with open('/Users/will/Documents/GitHub/Bias-in-ASR/test.json', 'r') as file:
    # Parse the JSON data and convert it into a Python object
    data8 = json.load(file)
rows_list8 = []
for item in data8["rows"]:
    row_data = item["row"]
    rows_list8.append({
        "row_idx": item["row_idx"],
        "id": row_data["id"],
        "speaker_id": row_data["speaker_id"],
        "chapter_id": row_data["chapter_id"],
        "audio_url": row_data["audio"][0]["src"],
        "text": row_data["text"]
    })
df8 = pd.DataFrame(rows_list8)
df8
# Out:
#     row_idx                id  speaker_id  chapter_id  \
# 0         0   6930-75918-0000        6930       75918
# 1         1   6930-75918-0001        6930       75918
# 2         2   6930-75918-0002        6930       75918
# 3         3   6930-75918-0003        6930       75918
# 4         4   6930-75918-0004        6930       75918
# ..      ...               ...         ...         ...
# 95       95  1320-122617-0017        1320      122617
# 96       96  1320-122617-0018        1320      122617
# 97       97  1320-122617-0019        1320      122617
# 98       98  1320-122617-0020        1320      122617
# 99       99  1320-122617-0021        1320      122617
#
#                                             audio_url  \
# 0   https://datasets-server.huggingface.co/cached-...
# 1   https://datasets-server.huggingface.co/cached-...
# 2   https://datasets-server.huggingface.co/cached-...
# 3   https://datasets-server.huggingface.co/cached-...
# ...
